# %% [markdown]
# <a href="https://colab.research.google.com/github/dutta-arka/Transit-Detect/blob/main/Vetting/TIC_188768068_Vetting_Results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install triceratops

# %%
# !pip install lightkurve

# %%
import numpy as np
import pandas as pd
import time
import lightkurve as lk
from lightkurve import TessLightCurve
import matplotlib.pyplot as plt
# %matplotlib inline

import triceratops.triceratops as tr

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the data from the CSV file
# .csv file is directly from SHERLOCKPIPE out product
data = pd.read_csv("lc_0.csv")

# Extract the values from each column
x = data.iloc[:, 0]
y = data.iloc[:, 1]
error = data.iloc[:, 2]

# LightCurve object
lc = lk.LightCurve(time=x, flux=y, flux_err=error)#.bin(time_bin_size=0.008)
lc = lc.remove_nans()

# Perform phase folding around the given epoch
tic_id = 188768068
period = 2.17796337607701  # Orbital period in days
epoch = 1766.04481375729
folded_lc = lc.fold(period=period, epoch_time=epoch)
folded_lc = folded_lc[folded_lc.time < 0.25]
folded_lc = folded_lc[folded_lc.time > -0.25]

# Plot the data with error bars
# plt.errorbar(x, y, fmt='o', markersize=3, capsize=2)

# # Plot a dotted line connecting the y-values
# plt.plot(x, y, linestyle=':', color='black')

# plt.xlabel('X')
# plt.ylabel('Y')
# plt.title('Folded light curve')
# plt.gcf().set_size_inches(15, 8)
# plt.grid(True)
# plt.show()

# Create a DataFrame with the required columns
folded_data = pd.DataFrame({
    'Time': folded_lc.time.value,  # Convert time to array
    'Flux': folded_lc.flux.value,  # Convert flux to array
    'Flux Error': folded_lc.flux_err.value  # Convert flux error to array
})

# Save the phase-folded light curve to a CSV file without column headers
output_filename = f"TIC_{tic_id}_all_sector_lightcurve.csv"
folded_data.to_csv(output_filename, index=False, header=False)

print(f"Phase-folded light curve saved to: {output_filename}")
# Out:
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]
# WARNING:astroquery:TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days
# Phase-folded light curve saved to: TIC_188768068_all_sector_lightcurve.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file
data = pd.read_csv(f'TIC_{tic_id}_all_sector_lightcurve.csv')

# Extract the x and y values from the dataset
x = data.iloc[:, 0]  # Assuming the first column is the x-axis
y = data.iloc[:, 1]  # Assuming the second column is the y-axis

# Set the figure size
plt.figure(figsize=(15, 7))

# Create a scatter plot
plt.scatter(x, y, marker='.')

# Add labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot')

# Show the plot
plt.show()

# %%
ID = tic_id
sectors = np.array([17, 20, 24, 25, 26]) # <, 40, 47, 50, 51, 53, 54, 57, 60>
target = tr.target(ID=ID, sectors=sectors, search_radius=6) # target radius shorted

# %%
ap_17 = np.array([[1687.0, 219.0], [1687.0, 220.0], [1688.0, 218.0], [1688.0, 219.0],
      [1688.0, 220.0], [1688.0, 221.0], [1688.0, 222.0], [1689.0, 218.0], [1689.0,
        219.0], [1689.0, 220.0], [1689.0, 221.0], [1689.0, 222.0], [1689.0, 223.0],
      [1690.0, 218.0], [1690.0, 219.0], [1690.0, 220.0], [1690.0, 221.0], [1690.0,
        222.0], [1690.0, 223.0], [1691.0, 218.0], [1691.0, 219.0], [1691.0, 220.0],
      [1691.0, 221.0], [1691.0, 222.0], [1691.0, 223.0], [1691.0, 224.0], [1692.0,
        218.0], [1692.0, 219.0], [1692.0, 220.0], [1692.0, 221.0], [1692.0, 222.0],
      [1692.0, 223.0], [1692.0, 224.0], [1693.0, 218.0], [1693.0, 219.0], [1693.0,
        220.0], [1693.0, 221.0], [1693.0, 222.0], [1693.0, 223.0]])
#         667.0], [1693.0, 668.0], [1693.0, 669.0], [1694.0, 663.0], [1694.0, 664.0],
#       [1694.0, 665.0], [1694.0, 666.0], [1694.0, 667.0], [1694.0, 668.0], [1695.0,
#         663.0], [1695.0, 664.0]])
# ap_60 = np.array([[518.0, 312.0], [518.0, 313.0], [518.0, 314.0],
#       [518.0, 315.0], [518.0, 316.0], [519.0, 312.0], [519.0, 313.0], [519.0, 314.0],
#       [519.0, 315.0], [519.0, 316.0], [519.0, 317.0], [520.0, 312.0], [520.0, 313.0],
#       [520.0, 314.0], [520.0, 315.0], [520.0, 316.0], [520.0, 317.0], [520.0, 318.0],
#       [521.0, 312.0], [521.0, 313.0], [521.0, 314.0], [521.0, 315.0], [521.0, 316.0],
#       [521.0, 317.0], [522.0, 312.0], [522.0, 313.0], [522.0, 314.0], [522.0, 315.0],
#       [522.0, 316.0], [522.0, 317.0], [523.0, 313.0], [523.0, 314.0], [523.0, 315.0],
#       [523.0, 316.0], [524.0, 313.0]])

apertures = np.array([ap_17, ap_20, ap_24, ap_25, ap_26]) # <, ap_40, ap_47, ap_50, ap_51, ap_53, ap_54, ap_57, ap_60>

for i,(sector,aperture) in enumerate(zip(sectors,apertures)):
    print("Sector", sector)
    target.plot_field(sector=sector, ap_pixels=aperture)

target.stars
# Out:
# <ipython-input-7-1002d4520bc9>:122: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   apertures = np.array([ap_17, ap_20, ap_24, ap_25, ap_26]) # <, ap_40, ap_47, ap_50, ap_51, ap_53, ap_54, ap_57, ap_60>
# Sector 17
# Sector 20
# Sector 24
# Sector 25
# Sector 26
#             ID     Tmag    Jmag    Hmag    Kmag          ra        dec  mass  \
# 0    188768068   5.8961   5.269   5.026   4.965  261.350233  52.790686  1.04
# 1    188771876  14.8700  14.370  13.965  14.205  261.357022  52.787685   NaN
# 2   1400677728  15.6366     NaN     NaN     NaN  261.335622  52.791085  0.81
# 3   1400677729  16.1646     NaN     NaN     NaN  261.333997  52.791713  0.64
# 4   1400677725  19.8984     NaN     NaN     NaN  261.340089  52.780772   NaN
# ...

# %%
tdepth = 0.06502 / 1000
target.calc_depths(tdepth=tdepth, all_ap_pixels=apertures)
target.stars
# Out:
# WARNING: 188771876 is missing stellar properties. If a mass (in M_Sun), radius (in R_Sun), and/or Teff (in K) are not added to the .stars dataframe, Solar values will be assumed.
#             ID     Tmag    Jmag    Hmag    Kmag          ra        dec  mass  \
# 0    188768068   5.8961   5.269   5.026   4.965  261.350233  52.790686  1.04
# 1    188771876  14.8700  14.370  13.965  14.205  261.357022  52.787685   NaN
# 2   1400677728  15.6366     NaN     NaN     NaN  261.335622  52.791085  0.81
# 3   1400677729  16.1646     NaN     NaN     NaN  261.333997  52.791713  0.64
# 4   1400677725  19.8984     NaN     NaN     NaN  261.340089  52.780772   NaN
# 5   1400677724  19.5457     NaN     NaN     NaN  261.335922  52.782502   NaN
# 6   1400677732  19.5070     NaN     NaN     NaN  261.358015  52.778785   NaN
# 7   1400677723  19.6256     NaN     NaN     NaN  261.331500  52.782729   NaN
# 8    188768073  16.4817  15.724  15.202  14.945  261.366746  52.779860  0.85
# ...

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# %%time

# read in the light curve
lc = pd.read_csv(f"TIC_{ID}_all_sector_lightcurve.csv", header=None)
time, flux, flux_err = lc[0].values, lc[1].values, lc[2].values
P_orb = period

lc_binsize = (time.max()-time.min())/200
lc = TessLightCurve(time=time, flux=flux, flux_err=flux_err).bin(time_bin_size=lc_binsize)

target.calc_probs(time=lc.time.value, flux_0=lc.flux.value, flux_err_0=np.mean(lc.flux_err.value), P_orb=P_orb,
                  parallel=True)
# Out:
# Calculating TP scenario probabilitiey for 188768068.
# Calculating EB and EBx2P scenario probabilities for 188768068.
# Calculating PTP scenario probability for 188768068.
# Calculating PEB and PEBx2P scenario probabilities for 188768068.
# Calculating STP scenario probability for 188768068.
# Calculating SEB and SEBx2P scenario probabilities for 188768068.
# Calculating DTP scenario probability for 188768068.
# Calculating DEB and DEBx2P scenario probabilities for 188768068.
# Calculating BTP scenario probability for 188768068.
# Calculating BEB and BEBx2P scenario probabilities for 188768068.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 188771876.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 1400677728.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 1400677729.
# CPU times: user 9min 1s, sys: 11 s, total: 9min 12s
# Wall time: 6min 19s

# %%
df_results = target.probs
print("FPP =", np.round(target.FPP, 8))
print("NFPP =", np.round(target.NFPP, 8))
df_results
# Out:
# FPP = 0.07016726
# NFPP = 0.0
#             ID scenario       M_s       R_s     P_orb        inc         b  \
# 0    188768068       TP  1.040000  1.264420  2.177963  83.706300  0.347604
# 1    188768068       EB  1.040000  1.264420  2.177963  68.744538  1.489509
# 2    188768068    EBx2P  1.040000  1.264420  4.355927  83.972374  0.556230
# 3    188768068      PTP  1.040000  1.264420  2.177963  83.182050  0.312779
# 4    188768068      PEB  1.040000  1.264420  2.177963  66.995920  1.731566
# 5    188768068   PEBx2P  1.040000  1.264420  4.355927  83.660739  0.894416
# 6    188768068      STP  0.311501  0.327631  2.177963  88.772812  0.173449
# 7    188768068      SEB  0.104152  0.125888  2.177963  87.493305  1.217535
# 8    188768068   SEBx2P  0.112643  0.137432  4.355927  89.069406  0.287242
# 9    188768068      DTP  1.040000  1.264420  2.177963  82.839523  0.541713
# 10   188768068      DEB  1.040000  1.264420  2.177963  68.007173  1.523484
# ...

# %%
target.plot_fits(time=lc.time.value, flux_0=lc.flux.value, flux_err_0=np.mean(lc.flux_err.value))

# %%
# %%time
# Repetations reduced
FPPs = np.zeros(10)
NFPPs = np.zeros(10)
for i in range(10):
    target.calc_probs(time=lc.time.value,
                      flux_0=lc.flux.value,
                      flux_err_0=np.mean(lc.flux_err.value),
                      P_orb=P_orb,
                      parallel=True,
                      verbose=0)
    FPPs[i] = target.FPP
    NFPPs[i] = target.NFPP

meanFPP = np.mean(FPPs)
stdvFPP = np.std(FPPs)
print("FPP =", meanFPP, "+/-", stdvFPP)

meanNFPP = np.mean(NFPPs)
stdvNFPP = np.std(NFPPs)
print("NFPP =", meanNFPP, "+/-", stdvNFPP)
# Out:
# FPP = 0.35464910948726913 +/- 0.36886342808792566
# NFPP = 1.2382787993195906e-29 +/- 1.1568234226405711e-29
# CPU times: user 1h 28min 53s, sys: 1min 40s, total: 1h 30min 33s
# Wall time: 1h 1min 1s

# %% [markdown]
# Our final conclusion about this specified planet of TIC 188768068 is that it is most likely a planet (according to the range of FPP and NFPP set by TRICERATOPS).
