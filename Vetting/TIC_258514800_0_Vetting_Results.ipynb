# %% [markdown]
# <a href="https://colab.research.google.com/github/dutta-arka/Transit-Detect/blob/main/Vetting/TIC_258514800_0_Vetting_Results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install triceratops

# %%
# !pip install lightkurve

# %%
import numpy as np
import pandas as pd
import time
import lightkurve as lk
from lightkurve import TessLightCurve
import matplotlib.pyplot as plt
# %matplotlib inline

import triceratops.triceratops as tr

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the data from the CSV file
# .csv file is directly from SHERLOCKPIPE out product
data = pd.read_csv("lc_0.csv")

# Extract the values from each column
x = data.iloc[:, 0]
y = data.iloc[:, 1]
error = data.iloc[:, 2]

# LightCurve object
lc = lk.LightCurve(time=x, flux=y, flux_err=error)#.bin(time_bin_size=0.005)
lc = lc.remove_nans()

# Perform phase folding around the given epoch
tic_id = 258514800
period = 0.47027625335861  # Orbital period in days
epoch = 1711.83285828771
folded_lc = lc.fold(period=period, epoch_time=epoch)
folded_lc = folded_lc[folded_lc.time < 0.1]
folded_lc = folded_lc[folded_lc.time > -0.1]

# Plot the data with error bars
# plt.errorbar(x, y, fmt='o', markersize=3, capsize=2)

# # Plot a dotted line connecting the y-values
# plt.plot(x, y, linestyle=':', color='black')

# plt.xlabel('X')
# plt.ylabel('Y')
# plt.title('Folded light curve')
# plt.gcf().set_size_inches(15, 8)
# plt.grid(True)
# plt.show()

# Create a DataFrame with the required columns
folded_data = pd.DataFrame({
    'Time': folded_lc.time.value,  # Convert time to array
    'Flux': folded_lc.flux.value,  # Convert flux to array
    'Flux Error': folded_lc.flux_err.value  # Convert flux error to array
})

# Save the phase-folded light curve to a CSV file without column headers
output_filename = f"TIC_{tic_id}_all_sector_lightcurve.csv"
folded_data.to_csv(output_filename, index=False, header=False)

print(f"Phase-folded light curve saved to: {output_filename}")
# Out:
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]
# WARNING:astroquery:TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days
# Phase-folded light curve saved to: TIC_258514800_all_sector_lightcurve.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file
data = pd.read_csv(f'TIC_{tic_id}_all_sector_lightcurve.csv')

# Extract the x and y values from the dataset
x = data.iloc[:, 0]  # Assuming the first column is the x-axis
y = data.iloc[:, 1]  # Assuming the second column is the y-axis

# Set the figure size
plt.figure(figsize=(15, 7))

# Create a scatter plot
plt.scatter(x, y, marker='.')

# Add labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot')

# Show the plot
plt.show()

# %%
ID = tic_id
sectors = np.array([15, 16, 17, 18, 19, 22, 24, 25, 26, 49]) # <, 52, 56, 57, 58, 59, 60>
target = tr.target(ID=ID, sectors=sectors, search_radius=6) # target radius shorted

# %%
ap_15 = np.array([[89.0, 296.0], [89.0, 297.0], [89.0, 298.0], [90.0, 296.0], [90.0,
        297.0], [90.0, 298.0], [90.0, 299.0], [91.0, 296.0], [91.0, 297.0], [91.0,
        298.0], [91.0, 299.0], [91.0, 300.0], [92.0, 297.0], [92.0, 298.0], [92.0,
        299.0]])
ap_16 = np.array([[866.0, 1085.0], [866.0, 1086.0], [866.0, 1087.0], [867.0, 1084.0],
      [867.0, 1085.0], [867.0, 1086.0], [867.0, 1087.0], [868.0, 1084.0], [868.0,
        1085.0], [868.0, 1086.0], [868.0, 1087.0], [868.0, 1088.0], [869.0, 1084.0],
      [869.0, 1085.0], [869.0, 1086.0], [869.0, 1087.0], [870.0, 1085.0], [870.0,
        1086.0]])
ap_17 = np.array([[1802.0, 238.0], [1802.0, 239.0], [1802.0, 240.0], [1803.0,
        237.0], [1803.0, 238.0], [1803.0, 239.0], [1803.0, 240.0], [1804.0, 237.0],
      [1804.0, 238.0], [1804.0, 239.0], [1804.0, 240.0], [1805.0, 237.0], [1805.0,
#       [1451.0, 472.0], [1452.0, 469.0], [1452.0, 470.0], [1452.0, 471.0], [1452.0,
#         472.0], [1453.0, 469.0], [1453.0, 470.0], [1453.0, 471.0], [1453.0, 472.0],
#       [1454.0, 470.0], [1454.0, 471.0]])
# ap_58 = np.array([[422.0, 449.0], [422.0, 450.0], [423.0,
#         448.0], [423.0, 449.0], [423.0, 450.0], [423.0, 451.0], [424.0, 448.0], [
#         424.0, 449.0], [424.0, 450.0], [424.0, 451.0], [425.0, 448.0], [425.0, 449.0],
#       [425.0, 450.0], [425.0, 451.0], [426.0, 449.0]])
# ap_59 = np.array([[700.0, 101.0], [700.0,
#         102.0], [700.0, 103.0], [701.0, 101.0], [701.0, 102.0], [701.0, 103.0], [
#         701.0, 104.0], [702.0, 101.0], [702.0, 102.0], [702.0, 103.0], [702.0, 104.0],
#       [703.0, 102.0], [703.0, 103.0]])
# ap_60 = np.array([[104.0, 1010.0], [104.0, 1011.0], [104.0,
#         1012.0], [105.0, 1010.0], [105.0, 1011.0], [105.0, 1012.0], [105.0, 1013.0],
#       [106.0, 1010.0], [106.0, 1011.0], [106.0, 1012.0], [106.0, 1013.0], [107.0,
#         1010.0], [107.0, 1011.0], [107.0, 1012.0]])

apertures = np.array([ap_15, ap_16, ap_17, ap_18, ap_19, ap_22, ap_24, ap_25, ap_26, ap_49]) # <, ap_52, ap_56, ap_57, ap_58, ap_59, ap_60>

for i,(sector,aperture) in enumerate(zip(sectors,apertures)):
    print("Sector", sector)
    target.plot_field(sector=sector, ap_pixels=aperture)

target.stars
# Out:
# <ipython-input-7-048ef5e772c7>:69: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   apertures = np.array([ap_15, ap_16, ap_17, ap_18, ap_19, ap_22, ap_24, ap_25, ap_26, ap_49]) # <, ap_52, ap_56, ap_57, ap_58, ap_59, ap_60>
# Sector 15
# Sector 16
# Sector 17
# Sector 18
# Sector 19
# Sector 22
# Sector 24
# Sector 25
# Sector 26
# Sector 49
#             ID     Tmag    Jmag    Hmag    Kmag          ra        dec  \
# 0    258514800  10.1522   9.465   9.087   9.061  305.474313  70.943794
# 1    258514801  16.6975  15.433  14.806  14.411  305.489676  70.946832
# 2   1981497192  19.0530     NaN     NaN     NaN  305.490804  70.946525
# 3    258514806  16.8136  15.797  15.123  15.022  305.458214  70.952460
# ...

# %%
tdepth = 0.118 / 1000
target.calc_depths(tdepth=tdepth, all_ap_pixels=apertures)
target.stars
# Out:
# WARNING: 1981497192 is missing stellar properties. If a mass (in M_Sun), radius (in R_Sun), and/or Teff (in K) are not added to the .stars dataframe, Solar values will be assumed.
# WARNING: 1981497185 is missing stellar properties. If a mass (in M_Sun), radius (in R_Sun), and/or Teff (in K) are not added to the .stars dataframe, Solar values will be assumed.
#             ID     Tmag    Jmag    Hmag    Kmag          ra        dec  \
# 0    258514800  10.1522   9.465   9.087   9.061  305.474313  70.943794
# 1    258514801  16.6975  15.433  14.806  14.411  305.489676  70.946832
# 2   1981497192  19.0530     NaN     NaN     NaN  305.490804  70.946525
# 3    258514806  16.8136  15.797  15.123  15.022  305.458214  70.952460
# 4    258514807  16.3299  14.747  14.079  13.857  305.464468  70.953800
# 5   1981497185  19.0942     NaN     NaN     NaN  305.495736  70.934973
# 6   1981497186  19.8734     NaN     NaN     NaN  305.496507  70.934906
# ...

# %%
# %%time

# read in the light curve
lc = pd.read_csv(f"TIC_{ID}_all_sector_lightcurve.csv", header=None)
time, flux, flux_err = lc[0].values, lc[1].values, lc[2].values
P_orb = period

lc_binsize = (time.max()-time.min())/80
lc = TessLightCurve(time=time, flux=flux, flux_err=flux_err).bin(time_bin_size=lc_binsize)

target.calc_probs(time=lc.time.value, flux_0=lc.flux.value, flux_err_0=np.mean(lc.flux_err.value), P_orb=P_orb,
                  parallel=True)
# Out:
# Calculating TP scenario probabilitiey for 258514800.
# Calculating EB and EBx2P scenario probabilities for 258514800.
# Calculating PTP scenario probability for 258514800.
# Calculating PEB and PEBx2P scenario probabilities for 258514800.
# Calculating STP scenario probability for 258514800.
# Calculating SEB and SEBx2P scenario probabilities for 258514800.
# Calculating DTP scenario probability for 258514800.
# Calculating DEB and DEBx2P scenario probabilities for 258514800.
# Calculating BTP scenario probability for 258514800.
# Calculating BEB and BEBx2P scenario probabilities for 258514800.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 258514801.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 1981497192.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 258514806.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 258514807.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 1981497185.
# ...

# %%
df_results = target.probs
print("FPP =", np.round(target.FPP, 8))
print("NFPP =", np.round(target.NFPP, 8))
df_results
# Out:
# FPP = 0.08247899
# NFPP = 0.00269141
#             ID scenario       M_s       R_s     P_orb        inc         b  \
# 0    258514800       TP  0.956000  0.924990  0.470276  80.298961  0.344733
# 1    258514800       EB  0.956000  0.924990  0.470276  49.952480  1.640702
# 2    258514800    EBx2P  0.956000  0.924990  0.940553  75.667802  0.848889
# 3    258514800      PTP  0.956000  0.924990  0.470276  80.948906  0.302832
# 4    258514800      PEB  0.956000  0.924990  0.470276  40.222624  1.858786
# 5    258514800   PEBx2P  0.956000  0.924990  0.940553  75.936472  0.975648
# 6    258514800      STP  0.923449  0.924990  0.470276  78.310827  0.435462
# 7    258514800      SEB  0.152650  0.184379  0.470276  84.935015  0.290994
# 8    258514800   SEBx2P  0.245440  0.270673  0.940553  84.704490  0.506516
# 9    258514800      DTP  0.956000  0.924990  0.470276  80.576805  0.310480
# 10   258514800      DEB  0.956000  0.924990  0.470276  48.954592  1.636588
# ...

# %%
target.plot_fits(time=lc.time.value, flux_0=lc.flux.value, flux_err_0=np.mean(lc.flux_err.value))

# %%
# %%time
# Repetion reduced
FPPs = np.zeros(10)
NFPPs = np.zeros(10)
for i in range(10):
    target.calc_probs(time=lc.time.value,
                      flux_0=lc.flux.value,
                      flux_err_0=np.mean(lc.flux_err.value),
                      P_orb=P_orb,
                      parallel=True,
                      verbose=0)
    FPPs[i] = target.FPP
    NFPPs[i] = target.NFPP

meanFPP = np.mean(FPPs)
stdvFPP = np.std(FPPs)
print("FPP =", meanFPP, "+/-", stdvFPP)

meanNFPP = np.mean(NFPPs)
stdvNFPP = np.std(NFPPs)
print("NFPP =", meanNFPP, "+/-", stdvNFPP)
# Out:
# FPP = 0.0830333472324461 +/- 0.002606505917569115
# NFPP = 0.002628444690241537 +/- 7.092924155041098e-05
# CPU times: user 3h 49min 21s, sys: 2min 25s, total: 3h 51min 46s
# Wall time: 2h 22min 41s

# %% [markdown]
# Our final conclusion about this specified planet of TIC 258514800 is that it is most likely a planet (according to the range of FPP and NFPP set by TRICERATOPS).
